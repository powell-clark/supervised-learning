# %% [markdown]
# Fixture without a lesson title

# %% [markdown]
# This revolutionary and awesome notebook is industry-standard. 🚀🎉
#
# It shows $x$ only once, and costs \$5 in compute, which is not mathematics.

# %%
x = 1
