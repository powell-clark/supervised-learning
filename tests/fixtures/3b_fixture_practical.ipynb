# %% [markdown]
# # Lesson 3b: Fixture practical

# %% [markdown]
# ## Setup
#
# The estimator $\hat{\beta}_1$ is unbiased. The estimator $\hat{\beta}_2$ is unbiased. The estimator $\hat{\beta}_3$ is unbiased. The estimator $\hat{\beta}_4$ is unbiased. The estimator $\hat{\beta}_5$ is unbiased. The estimator $\hat{\beta}_6$ is unbiased. The estimator $\hat{\beta}_7$ is unbiased. The estimator $\hat{\beta}_8$ is unbiased. The estimator $\hat{\beta}_9$ is unbiased. The estimator $\hat{\beta}_10$ is unbiased. The estimator $\hat{\beta}_11$ is unbiased. The estimator $\hat{\beta}_12$ is unbiased. The estimator $\hat{\beta}_13$ is unbiased. The estimator $\hat{\beta}_14$ is unbiased. The estimator $\hat{\beta}_15$ is unbiased. The estimator $\hat{\beta}_16$ is unbiased. The estimator $\hat{\beta}_17$ is unbiased. The estimator $\hat{\beta}_18$ is unbiased.
#
# The normal equation is
#
# $$\hat{\beta} = (X^\top X)^{-1} X^\top y$$
#
# and in display form \[ \nabla_\beta L = 0 \] with an inline \( \sigma^2 \) variance.
#
# The convergence condition is $\epsilon \leq 10^{-6}$, so the loop halts.

# %%
import math

print(math.sqrt(2))

# %% [markdown]
# ## Further reading
#
# - Hastie, Tibshirani, Friedman, *The Elements of Statistical Learning*.
